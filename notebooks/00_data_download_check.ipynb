# %% [markdown]
# # 00 - Descarga de datos y validación de datos raw
# Descarga inicial de los datos desde la API de ClinicalTrials.gov (https://clinicaltrials.gov/data-api/api) utilizando el script `src/download_clinicaltrials.py`.
#
# - Verifica que el fichero con datos RAW se ha generado correctamente.
# - Carga una muestra para inspeccionar la estructura y coherencia.
# - Guarda el dataset para el Notebook 01 (EDA).
#
# **Nota: Este notebook solo debe ejecutarse cuando se desea descargar datos.** Idealmente ejecutar el notebook una sola vez, guardar el snapshot en `data/raw/`, y usar siempre ese archivo en el resto de notebooks.

# %%
from pathlib import Path
import pandas as pd
import datetime

import json

# Buscar cual es la ruta del proyecto, un nivel mas arriba que la ruta del notebook

PROJECT_ROOT = Path.cwd().parent
print("Proyecto cargado desde:", PROJECT_ROOT)

# Creamos las carpeta RAW y CLEAN para guardar los datos

RAW_DIR = PROJECT_ROOT / "data" / "raw"
CLEAN_DIR = PROJECT_ROOT / "data" / "clean"

RAW_DIR.mkdir(parents = True, exist_ok = True)
CLEAN_DIR.mkdir(parents = True, exist_ok = True)

print("\nCarpeta datos RAW:", RAW_DIR)
print("Carpeta datos CLEAN:", CLEAN_DIR)
# Out:
# Proyecto cargado desde: C:\Users\Administrador\Documents\tfm_clinicaltrials
#
# Carpeta datos RAW: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# Carpeta datos CLEAN: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\clean

# %%
# Ejecución del script de descarga
# Nota: el script de descarga filtra por `StudyType = Interventional`, registros posteriores a 2000 y que el campo Phase esté rellenado, usando `filter.advanced` en la API.

# %cd ..
# %run -m src.download_clinicaltrials 200
# Out:
# C:\Users\Administrador\Documents\tfm_clinicaltrials
# Descargando 200 filas
# Descargando todos los campos por defecto
# Descargando ensayos: 100%|██████████| 200/200 [00:02<00:00, 90.03ensayos/s]
# Alcanzado el número máximo de ensayos=200, parando la ejecución.
# Se han descargado 200 ensayos.
# Datos RAW guardados en: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251209_015930.csv

# %%
raw_files = list(RAW_DIR.glob("clinicaltrials_*.csv"))
raw_files_sorted = sorted(raw_files, key = lambda x: x.stat().st_mtime, reverse = True)

print("\nFicheros RAW mas recientes", RAW_DIR)

raw_files_sorted[:5]
# Out:
# Ficheros RAW mas recientes C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# [WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_015930.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011852.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011310.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011013.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_010901.csv')]

# %%
if not raw_files_sorted:
    raise FileNotFoundError("No hay ficheros en data/raw/. Necesario ejecutar el script de descarga.")

raw_file = raw_files_sorted[0]
print("Se usa el fichero mas reciente:", raw_file)

df_raw_check = pd.read_csv(raw_file, low_memory = False)
df_raw_check.head(20)
# Out:
# Se usa el fichero mas reciente: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251209_015930.csv
#    protocolSection.identificationModule.nctId  \
# 0                                 NCT01315821
# 1                                 NCT04551521
# 2                                 NCT04086121
# 3                                 NCT01181921
# 4                                 NCT05435014
# 5                                 NCT02497716
# 6                                 NCT01730716
# 7                                 NCT06236516
# 8                                 NCT05833906
# 9                                 NCT02157506
# 10                                NCT05664906
# 11                                NCT02711904
# 12                                NCT04019704
# 13                                NCT00720304
# 14                                NCT00729404
# 15                                NCT00591604
# 16                                NCT02978404
# 17                                NCT00991133
# 18                                NCT00863252
# 19                                NCT06736587
#
#    protocolSection.identificationModule.orgStudyIdInfo.id  \
# 0                                                1234
# 1                                        NCT-PMO-1602
# 2                                           1368-0037
# 3                                            CR015586
# 4                                       TACE-OHEP-001
# 5                                               17992
# 6                                            NS2012-3
# 7                                           202401015
# 8                                  COSMOS-21-RegenT-1
# 9                                         CXL-1427-02
# 10                                      CM Rinse_OMRT
# 11                                           SEGANEST
# 12                                     AXS-05-MDD-301
# 13                                           CASE5307
# 14                                              91558
# 15                                             06-250
# 16                                             16.206
# 17                                           CLO08808
# 18                                        Roche-ST-01
# 19                                    DW_DWP212525101
#
#    protocolSection.identificationModule.organization.fullName  \
# 0   Zekai Tahir Burak Women's Health Research and ...
# 1                       German Cancer Research Center
# 2                                Boehringer Ingelheim
# 3                                 Janssen-Cilag, S.A.
# 4                              T-ACE Medical Co., Ltd
# 5                                               Bayer
# 6                                     Neuralstem Inc.
# 7            Washington University School of Medicine
# 8                                      CK Regeon Inc.
# 9                                Bristol-Myers Squibb
# 10                    Chinese University of Hong Kong
# 11                                           Seganest
# 12                          Axsome Therapeutics, Inc.
# 13                   Case Comprehensive Cancer Center
# 14                                              Bayer
# 15  The University of Texas Medical Branch, Galveston
# 16  Centre hospitalier de l'Université de Montréal...
# 17                                             Sanofi
# 18                        The University of Hong Kong
# 19                   Daewoong Pharmaceutical Co. LTD.
#
#    protocolSection.identificationModule.organization.class  \
# 0                                               OTHER
# 1                                               OTHER
# 2                                            INDUSTRY
# 3                                            INDUSTRY
# 4                                            INDUSTRY
# 5                                            INDUSTRY
# 6                                            INDUSTRY
# 7                                               OTHER
# 8                                            INDUSTRY
# 9                                            INDUSTRY
# 10                                              OTHER
# 11                                              OTHER
# 12                                           INDUSTRY
# 13                                              OTHER
# 14                                           INDUSTRY
# 15                                              OTHER
# 16                                              OTHER
# 17                                           INDUSTRY
# 18                                              OTHER
# 19                                           INDUSTRY
#
#       protocolSection.identificationModule.briefTitle  \
# 0   Effect of Saccharomyces Boulardii on Necrotizi...
# 1              CRAFT: The NCT-PMO-1602 Phase II Trial
# 2   A Study to Test the Long-term Safety of BI 655...
# 3   The CIRCADIAN Study: Evaluation of Modulating ...
# 4   T-ACE Oil by TAE/TACE in Patients With Hepatoc...
# 5   Phase I Study on Rivaroxaban Granules for Oral...
# 6   Dose Escalation and Safety Study of Human Spin...
# 7   One Fraction Simulation-Free Treatment With CT...
# 8   Safety, Tolerability, and Pharmacokinetic Eval...
# 9   A Dose Ranging Phase IIa Study of 6 Hour Intra...
# 10  Evaluating Chinese Medicine Oral Rinse for Irr...
# 11      Concentrations of Remifentanil for Extubation
# 12  A Trial of AXS-05 in Patients With Major Depre...
# 13  Erlotinib, Docetaxel, and Radiation Therapy in...
# 14  Inhibition of Ovulation, Patch, Ethinylestradi...
# 15      High-Dose Vitamin D Deficiency in Burn Injury
# 16  Combining Radiosurgery and Nivolumab in the Tr...
# 17  A Safety and Tolerability Study of Clofarabine...
# 18          Mycophenolate Mofetil for IgA Nephropathy
# 19  A Randomized, Double-blind, Placebo-controlled...
#
#    protocolSection.identificationModule.officialTitle  \
# 0   Role Of Saccharomyces Boulardii in Preventin N...
# 1   Continuous ReAssessment With Flexible ExTensio...
# 2   An Open Label Extension Study to Assess the Lo...
# 3   Phase IV Study for the Assessment of Modulatin...
# 4   Phase I/II Randomized, Double-Blind, First-in-...
# 5   Single-dose Study Testing Rivaroxaban Granules...
# 6   A Phase II, Open-label, Dose Escalation and Sa...
# 7   One Fraction Simulation-Free Treatment With CT...
# 8   A Randomized, Single-blind, Placebo-controlled...
# 9   A Phase IIa Study of the Safety, Tolerability ...
# 10  Evaluating Efficacy and Safety of Chinese Medi...
# 11  Effect of Two Plasma Concentrations of Remifen...
# 12  AXS-05-MDD-301: A Randomized, Double-Blind, Pl...
# 13  A Phase II Study of the Epidermal Growth Facto...
# 14  Multicenter, Open-label, Randomized, Uncontrol...
# 15  Use of High-Dose Vitamin D to Treat Vitamin D ...
# 16  A Phase II, Multi-centre Study, of Combining R...
# 17  A Phase 1, Open-Label, Multi-Center Safety and...
# 18  A Prospective, Randomized, Open Label, Case-Co...
# 19  A Randomized, Double-blind, Placebo-controlled...
#
#    protocolSection.statusModule.statusVerifiedDate  \
# 0                                          2011-02
# 1                                          2024-05
# 2                                          2025-02
# 3                                          2014-04
# 4                                          2024-11
# 5                                          2019-04
# 6                                          2013-05
# 7                                          2025-08
# 8                                          2024-01
# 9                                          2019-07
# 10                                         2022-12
# 11                                         2016-03
# 12                                         2022-09
# 13                                         2024-08
# 14                                         2014-11
# 15                                         2012-11
# 16                                         2024-06
# 17                                         2015-04
# 18                                         2009-03
# 19                                         2024-12
#
#    protocolSection.statusModule.overallStatus  \
# 0                                     UNKNOWN
# 1                                   COMPLETED
# 2                                  TERMINATED
# 3                                  TERMINATED
# 4                                  RECRUITING
# 5                                   COMPLETED
# 6                                     UNKNOWN
# 7                                   COMPLETED
# 8                                   COMPLETED
# 9                                   COMPLETED
# 10                                    UNKNOWN
# 11                                  COMPLETED
# 12                                  COMPLETED
# 13                                  COMPLETED
# 14                                 TERMINATED
# 15                                  WITHDRAWN
# 16                                  COMPLETED
# 17                                  COMPLETED
# 18                                  COMPLETED
# 19                                 RECRUITING
#
#    protocolSection.statusModule.lastKnownStatus  \
# 0                                    RECRUITING
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                         ACTIVE_NOT_RECRUITING
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                           NOT_YET_RECRUITING
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
#
#    protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess  ...  \
# 0                                               False                 ...
# 1                                               False                 ...
# 2                                               False                 ...
# 3                                               False                 ...
# 4                                               False                 ...
# 5                                               False                 ...
# 6                                               False                 ...
# 7                                               False                 ...
# 8                                               False                 ...
# 9                                               False                 ...
# 10                                              False                 ...
# 11                                              False                 ...
# 12                                              False                 ...
# 13                                              False                 ...
# 14                                              False                 ...
# 15                                              False                 ...
# 16                                              False                 ...
# 17                                              False                 ...
# 18                                              False                 ...
# 19                                              False                 ...
#
#    resultsSection.moreInfoModule.pointOfContact.phoneExt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.eligibilityModule.genderBased  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
#
#    protocolSection.eligibilityModule.genderDescription  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.date  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.type  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.identificationModule.orgStudyIdInfo.type  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.identificationModule.orgStudyIdInfo.link  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.statusModule.expandedAccessInfo.nctId  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.statusModule.expandedAccessInfo.statusForNctId  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.identificationModule.nctIdAliases
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
#
# [20 rows x 130 columns]

# %%
print("Shape:", df_raw_check.shape)
print("\nColumnas:")
print(df_raw_check.columns.tolist())
# Out:
# Shape: (200, 130)
#
# Columnas:
# ['protocolSection.identificationModule.nctId', 'protocolSection.identificationModule.orgStudyIdInfo.id', 'protocolSection.identificationModule.organization.fullName', 'protocolSection.identificationModule.organization.class', 'protocolSection.identificationModule.briefTitle', 'protocolSection.identificationModule.officialTitle', 'protocolSection.statusModule.statusVerifiedDate', 'protocolSection.statusModule.overallStatus', 'protocolSection.statusModule.lastKnownStatus', 'protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess', 'protocolSection.statusModule.startDateStruct.date', 'protocolSection.statusModule.primaryCompletionDateStruct.date', 'protocolSection.statusModule.primaryCompletionDateStruct.type', 'protocolSection.statusModule.completionDateStruct.date', 'protocolSection.statusModule.completionDateStruct.type', 'protocolSection.statusModule.studyFirstSubmitDate', 'protocolSection.statusModule.studyFirstSubmitQcDate', 'protocolSection.statusModule.studyFirstPostDateStruct.date', 'protocolSection.statusModule.studyFirstPostDateStruct.type', 'protocolSection.statusModule.lastUpdateSubmitDate', 'protocolSection.statusModule.lastUpdatePostDateStruct.date', 'protocolSection.statusModule.lastUpdatePostDateStruct.type', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.oldNameTitle', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.oldOrganization', 'protocolSection.sponsorCollaboratorsModule.leadSponsor.name', 'protocolSection.sponsorCollaboratorsModule.leadSponsor.class', 'protocolSection.oversightModule.oversightHasDmc', 'protocolSection.descriptionModule.briefSummary', 'protocolSection.descriptionModule.detailedDescription', 'protocolSection.conditionsModule.conditions', 'protocolSection.conditionsModule.keywords', 'protocolSection.designModule.studyType', 'protocolSection.designModule.phases', 'protocolSection.designModule.designInfo.allocation', 'protocolSection.designModule.designInfo.interventionModel', 'protocolSection.designModule.designInfo.primaryPurpose', 'protocolSection.designModule.designInfo.maskingInfo.masking', 'protocolSection.designModule.designInfo.maskingInfo.whoMasked', 'protocolSection.designModule.enrollmentInfo.count', 'protocolSection.designModule.enrollmentInfo.type', 'protocolSection.armsInterventionsModule.armGroups', 'protocolSection.armsInterventionsModule.interventions', 'protocolSection.outcomesModule.primaryOutcomes', 'protocolSection.outcomesModule.secondaryOutcomes', 'protocolSection.eligibilityModule.eligibilityCriteria', 'protocolSection.eligibilityModule.healthyVolunteers', 'protocolSection.eligibilityModule.sex', 'protocolSection.eligibilityModule.minimumAge', 'protocolSection.eligibilityModule.maximumAge', 'protocolSection.eligibilityModule.stdAges', 'protocolSection.contactsLocationsModule.centralContacts', 'protocolSection.contactsLocationsModule.overallOfficials', 'protocolSection.contactsLocationsModule.locations', 'protocolSection.referencesModule.references', 'derivedSection.miscInfoModule.versionHolder', 'derivedSection.conditionBrowseModule.meshes', 'derivedSection.conditionBrowseModule.ancestors', 'hasResults', 'protocolSection.statusModule.startDateStruct.type', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.type', 'protocolSection.oversightModule.isFdaRegulatedDrug', 'protocolSection.oversightModule.isFdaRegulatedDevice', 'derivedSection.interventionBrowseModule.meshes', 'derivedSection.interventionBrowseModule.ancestors', 'protocolSection.statusModule.whyStopped', 'protocolSection.statusModule.resultsFirstSubmitDate', 'protocolSection.statusModule.resultsFirstSubmitQcDate', 'protocolSection.statusModule.resultsFirstPostDateStruct.date', 'protocolSection.statusModule.resultsFirstPostDateStruct.type', 'protocolSection.referencesModule.seeAlsoLinks', 'protocolSection.ipdSharingStatementModule.ipdSharing', 'protocolSection.ipdSharingStatementModule.description', 'resultsSection.participantFlowModule.preAssignmentDetails', 'resu ...

# %%
## 2. Selección de campos y renombrado

lista_columnas = [
    "protocolSection.identificationModule.nctId",
    "protocolSection.identificationModule.briefTitle",
    "protocolSection.identificationModule.officialTitle",
    "protocolSection.statusModule.overallStatus",
    "protocolSection.statusModule.lastKnownStatus",
    "protocolSection.statusModule.whyStopped",
    "protocolSection.statusModule.startDateStruct.date",
    "protocolSection.statusModule.primaryCompletionDateStruct.date",
    "protocolSection.statusModule.completionDateStruct.date",
    "protocolSection.designModule.studyType",
    "protocolSection.designModule.phases",
    "protocolSection.designModule.enrollmentInfo.count",
    "protocolSection.designModule.designInfo.allocation",
    "protocolSection.designModule.designInfo.interventionModel",
    "protocolSection.designModule.designInfo.primaryPurpose",
    "protocolSection.designModule.designInfo.maskingInfo.masking",
    "protocolSection.designModule.designInfo.maskingInfo.whoMasked",
    "protocolSection.conditionsModule.conditions",
    "protocolSection.conditionsModule.keywords",
    "protocolSection.contactsLocationsModule.locations",
    "protocolSection.armsInterventionsModule.interventions",
    "protocolSection.outcomesModule.primaryOutcomes",
    "protocolSection.outcomesModule.secondaryOutcomes",
    "protocolSection.descriptionModule.briefSummary",
    "protocolSection.sponsorCollaboratorsModule.leadSponsor.name",
    "protocolSection.sponsorCollaboratorsModule.leadSponsor.class",
    "protocolSection.sponsorCollaboratorsModule.collaborators",
    "protocolSection.eligibilityModule.minimumAge",
    "protocolSection.eligibilityModule.maximumAge",
    "protocolSection.eligibilityModule.sex",
    "protocolSection.eligibilityModule.healthyVolunteers",
    "protocolSection.eligibilityModule.eligibilityCriteria",
    "derivedSection.conditionBrowseModule.meshes",
    "derivedSection.interventionBrowseModule.meshes",
    "hasResults",
    "protocolSection.statusModule.lastUpdateSubmitDate",
    "protocolSection.statusModule.studyFirstSubmitDate",
    "protocolSection.ipdSharingStatementModule.ipdSharing",
]

# Observamos en https://clinicaltrials.gov/data-api/about-api/study-data-structure cuales son los nombres de los campos que se aceptan:

fields_api = [
    "NCTId", "BriefTitle", "OfficialTitle", "OverallStatus", "LastKnownStatus","WhyStopped", "StartDate", "PrimaryCompletionDate","CompletionDate",
    "StudyType", "Phase", "EnrollmentCount", "DesignAllocation", "DesignInterventionModel", "DesignPrimaryPurpose", "DesignMasking","DesignWhoMasked",
    "Condition","Keyword", "LocationCountry", "InterventionType","InterventionName", "PrimaryOutcomeMeasure","SecondaryOutcomeMeasure", "BriefSummary",
    "LeadSponsorName","LeadSponsorClass","CollaboratorName", "MinimumAge","MaximumAge","Sex","HealthyVolunteers", "EligibilityCriteria",
    "ConditionMeshTerm","InterventionMeshTerm", "HasResults", "LastUpdateSubmitDate","StudyFirstSubmitDate", "IPDSharing"
]

cols_str = " ".join(fields_api)

# %%
# %run -m src.download_clinicaltrials 300000 $cols_str
# Out:
# Descargando 300000 filas
# Usando columnas: ['NCTId', 'BriefTitle', 'OfficialTitle', 'OverallStatus', 'LastKnownStatus', 'WhyStopped', 'StartDate', 'PrimaryCompletionDate', 'CompletionDate', 'StudyType', 'Phase', 'EnrollmentCount', 'DesignAllocation', 'DesignInterventionModel', 'DesignPrimaryPurpose', 'DesignMasking', 'DesignWhoMasked', 'Condition', 'Keyword', 'LocationCountry', 'InterventionType', 'InterventionName', 'PrimaryOutcomeMeasure', 'SecondaryOutcomeMeasure', 'BriefSummary', 'LeadSponsorName', 'LeadSponsorClass', 'CollaboratorName', 'MinimumAge', 'MaximumAge', 'Sex', 'HealthyVolunteers', 'EligibilityCriteria', 'ConditionMeshTerm', 'InterventionMeshTerm', 'HasResults', 'LastUpdateSubmitDate', 'StudyFirstSubmitDate', 'IPDSharing']
# Descargando ensayos:  68%|██████▊   | 204675/300000 [05:38<02:37, 603.93ensayos/s]
# No existe nextPageToken, parando la ejecución.
# Se han descargado 204675 ensayos.
# Datos RAW guardados en: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251209_020512.csv

# %%
raw_files = list(RAW_DIR.glob("clinicaltrials_*.csv"))
raw_files_sorted = sorted(raw_files, key=lambda x: x.stat().st_mtime, reverse=True)

print("\nFicheros RAW mas recientes", RAW_DIR)

raw_files_sorted[:5]
# Out:
# Ficheros RAW mas recientes C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# [WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_020512.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_015930.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011852.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011310.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251209_011013.csv')]

# %%
if not raw_files_sorted:
    raise FileNotFoundError("No hay ficheros en data/raw/. Necesario ejecutar el script de descarga.")

raw_file = raw_files_sorted[0]
print("Se usa el fichero mas reciente:", raw_file)

df_raw = pd.read_csv(raw_file, low_memory=False)
df_raw.head()
# Out:
# Se usa el fichero mas reciente: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251209_020512.csv
#   protocolSection.identificationModule.nctId  \
# 0                                NCT01315821
# 1                                NCT04551521
# 2                                NCT04086121
# 3                                NCT01181921
# 4                                NCT05435014
#
#      protocolSection.identificationModule.briefTitle  \
# 0  Effect of Saccharomyces Boulardii on Necrotizi...
# 1             CRAFT: The NCT-PMO-1602 Phase II Trial
# 2  A Study to Test the Long-term Safety of BI 655...
# 3  The CIRCADIAN Study: Evaluation of Modulating ...
# 4  T-ACE Oil by TAE/TACE in Patients With Hepatoc...
#
#   protocolSection.identificationModule.officialTitle  \
# 0  Role Of Saccharomyces Boulardii in Preventin N...
# 1  Continuous ReAssessment With Flexible ExTensio...
# 2  An Open Label Extension Study to Assess the Lo...
# 3  Phase IV Study for the Assessment of Modulatin...
# 4  Phase I/II Randomized, Double-Blind, First-in-...
#
#   protocolSection.statusModule.overallStatus  \
# 0                                    UNKNOWN
# 1                                  COMPLETED
# 2                                 TERMINATED
# 3                                 TERMINATED
# 4                                 RECRUITING
#
#   protocolSection.statusModule.lastKnownStatus  \
# 0                                   RECRUITING
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   protocolSection.statusModule.startDateStruct.date  \
# 0                                           2011-02
# 1                                        2021-10-13
# 2                                        2019-09-24
# 3                                           2011-05
# 4                                        2022-09-13
#
#   protocolSection.statusModule.primaryCompletionDateStruct.date  \
# 0                                            2011-12
# 1                                         2024-12-30
# 2                                         2021-04-28
# 3                                            2011-06
# 4                                         2026-06-30
#
#   protocolSection.statusModule.completionDateStruct.date  \
# 0                                            2011-12
# 1                                         2024-12-30
# 2                                         2022-02-23
# 3                                            2011-06
# 4                                         2026-06-30
#
#   protocolSection.statusModule.studyFirstSubmitDate  \
# 0                                        2011-02-24
# 1                                        2020-07-24
# 2                                        2019-09-10
# 3                                        2010-08-12
# 4                                        2021-11-16
#
#   protocolSection.statusModule.lastUpdateSubmitDate  ...  \
# 0                                        2011-08-04  ...
# 1                                        2025-01-07  ...
# 2                                        2025-02-10  ...
# 3                                        2014-04-15  ...
# 4                                        2024-12-17  ...
#
#   protocolSection.eligibilityModule.sex  \
# 0                                   ALL
# 1                                   ALL
# 2                                   ALL
# 3                                   ALL
# 4                                   ALL
#
#   protocolSection.eligibilityModule.minimumAge  \
# 0                                        1 Day
# 1                                     18 Years
# 2                                     18 Years
# 3                                     18 Years
# 4                                     20 Years
#
#   protocolSection.eligibilityModule.maximumAge  \
# 0                                     2 Months
# 1                                          NaN
# 2                                     75 Years
# 3                                          NaN
# 4                                          NaN
#
#    protocolSection.contactsLocationsModule.locations  \
# 0                  [{"country": "Turkey (Türkiye)"}]
# 1  [{"country": "Germany"}, {"country": "Germany"...
# 2  [{"country": "United States"}, {"country": "Un...
# 3                             [{"country": "Spain"}]
# 4  [{"country": "Taiwan"}, {"country": "Taiwan"},...
#
#          derivedSection.conditionBrowseModule.meshes hasResults  \
# 0           [{"term": "Enterocolitis, Necrotizing"}]      False
# 1                  [{"term": "Neoplasm Metastasis"}]      False
# 2                   [{"term": "Dermatitis, Atopic"}]       True
# 3  [{"term": "Alzheimer Disease"}, {"term": "Deme...       True
# 4            [{"term": "Carcinoma, Hepatocellular"}]      False
#
#       derivedSection.interventionBrowseModule.meshes  \
# 0                                                NaN
# 1  [{"term": "Vemurafenib"}, {"term": "cobimetini...
# 2                           [{"term": "spesolimab"}]
# 3                          [{"term": "Galantamine"}]
# 4                       [{"term": "Ethiodized Oil"}]
#
#              protocolSection.statusModule.whyStopped  \
# 0                                                NaN
# 1                                                NaN
# 2                                   Sponsor decision
# 3  The recruitment rate was very low (one screeni...
# 4                                                NaN
#
#   protocolSection.ipdSharingStatementModule.ipdSharing  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 NO
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.sponsorCollaboratorsModule.collaborators
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 38 columns]

# %%
df_raw.columns[:10]
# Out:
# Index(['protocolSection.identificationModule.nctId',
#        'protocolSection.identificationModule.briefTitle',
#        'protocolSection.identificationModule.officialTitle',
#        'protocolSection.statusModule.overallStatus',
#        'protocolSection.statusModule.lastKnownStatus',
#        'protocolSection.statusModule.startDateStruct.date',
#        'protocolSection.statusModule.primaryCompletionDateStruct.date',
#        'protocolSection.statusModule.completionDateStruct.date',
#        'protocolSection.statusModule.studyFirstSubmitDate',
#        'protocolSection.statusModule.lastUpdateSubmitDate'],
#       dtype='object')

# %%
df_clean = df_raw.copy()

df_clean.columns = (df_clean.columns.str.lower())

rename_map = {
    "protocolsection.identificationmodule.nctid": "NCTId",
    "protocolsection.identificationmodule.brieftitle": "BriefTitle",
    "protocolsection.identificationmodule.officialtitle": "OfficialTitle",
    "protocolsection.sponsorcollaboratorsmodule.leadsponsor.name": "LeadSponsorName",
    "protocolsection.sponsorcollaboratorsmodule.leadsponsor.class": "LeadSponsorClass",
    "protocolsection.sponsorcollaboratorsmodule.collaborators": "CollaboratorName",
    "protocolsection.statusmodule.overallstatus": "OverallStatus",
    "protocolsection.statusmodule.lastknownstatus": "LastKnownStatus",
    "protocolsection.statusmodule.whystopped": "WhyStopped",
    "protocolsection.statusmodule.startdatestruct.date": "StartDate",
    "protocolsection.statusmodule.primarycompletiondatestruct.date": "PrimaryCompletionDate",
    "protocolsection.statusmodule.completiondatestruct.date": "CompletionDate",
    "protocolsection.statusmodule.lastupdatesubmitdate": "LastUpdateSubmitDate",
    "protocolsection.statusmodule.studyfirstsubmitdate": "StudyFirstSubmitDate",
    "protocolsection.designmodule.studytype": "StudyType",
    "protocolsection.designmodule.phases": "Phase",
    "protocolsection.designmodule.enrollmentinfo.count": "EnrollmentCount",
    "protocolsection.designmodule.enrollmentinfo.type": "EnrollmentType",
    "protocolsection.designmodule.designinfo.allocation": "DesignAllocation",
    "protocolsection.designmodule.designinfo.interventionmodel": "DesignInterventionModel",
    "protocolsection.designmodule.designinfo.primarypurpose": "DesignPrimaryPurpose",
    "protocolsection.designmodule.designinfo.maskinginfo.masking": "DesignMasking",
    "protocolsection.designmodule.designinfo.maskinginfo.whomasked": "DesignWhoMasked",
    "protocolsection.conditionsmodule.conditions": "Condition",
    "protocolsection.conditionsmodule.keywords": "Keyword",
    "protocolsection.contactslocationsmodule.locations": "LocationCountry",
    "protocolsection.armsinterventionsmodule.interventions": "InterventionName",
    "protocolsection.outcomesmodule.primaryoutcomes": "PrimaryOutcomeMeasure",
    "protocolsection.outcomesmodule.secondaryoutcomes": "SecondaryOutcomeMeasure",
    "protocolsection.descriptionmodule.briefsummary": "BriefSummary",
    "protocolsection.eligibilitymodule.minimumage": "MinimumAge",
    "protocolsection.eligibilitymodule.maximumage": "MaximumAge",
    "protocolsection.eligibilitymodule.sex": "Sex",
    "protocolsection.eligibilitymodule.healthyvolunteers": "HealthyVolunteers",
    "protocolsection.eligibilitymodule.eligibilitycriteria": "EligibilityCriteria",
    "derivedsection.conditionbrowsemodule.meshes": "ConditionMeshTerm",
    "derivedsection.interventionbrowsemodule.meshes": "InterventionMeshTerm",
    "hasresults": "HasResults",
    "protocolsection.ipdsharingstatementmodule.ipdsharing": "IPDSharing",
}



df_clean = df_clean.rename(columns=rename_map)


df_clean = df_clean.apply(lambda col: 
    col.astype(str)
       .str.replace("\n", " ", regex=False)
       .str.replace("\r", " ", regex=False)
    if col.dtype == "object" else col
)


df_clean
# Out:
#               NCTId                                         BriefTitle  \
# 0       NCT01315821  Effect of Saccharomyces Boulardii on Necrotizi...
# 1       NCT04551521             CRAFT: The NCT-PMO-1602 Phase II Trial
# 2       NCT04086121  A Study to Test the Long-term Safety of BI 655...
# 3       NCT01181921  The CIRCADIAN Study: Evaluation of Modulating ...
# 4       NCT05435014  T-ACE Oil by TAE/TACE in Patients With Hepatoc...
# ...             ...                                                ...
# 204670  NCT01596387  Validation of a Pharmacokinetic Pharmacodynami...
# 204671  NCT02919787       Nordic Pancreatic Cancer Trial (NorPACT) - 1
# 204672  NCT04954287  Phase 1 Study of Intranasal PIV5 COVID-19 Vacc...
# 204673  NCT06577987  Safety/Efficacy Study of CID-078 in Patients W...
# 204674  NCT01762293  A Study of Famitinib in Patients With Advanced...
#
#                                             OfficialTitle  \
# 0       Role Of Saccharomyces Boulardii in Preventin N...
# 1       Continuous ReAssessment With Flexible ExTensio...
# 2       An Open Label Extension Study to Assess the Lo...
# 3       Phase IV Study for the Assessment of Modulatin...
# 4       Phase I/II Randomized, Double-Blind, First-in-...
# ...                                                   ...
# 204670  Validation of a Pharmacokinetic Pharmacodynami...
# 204671  Nordic Multicentre Un-blinded Phase II Randomi...
# 204672  A Phase 1 Open-Label, Dose-Ranging Trial to Ev...
# 204673  A Phase 1, Open-Label, Multicenter Study to Ev...
# 204674  A Randomized, Placebo-controlled, Double-blind...
#
#                 OverallStatus LastKnownStatus   StartDate  \
# 0                     UNKNOWN      RECRUITING     2011-02
# 1                   COMPLETED             nan  2021-10-13
# 2                  TERMINATED             nan  2019-09-24
# 3                  TERMINATED             nan     2011-05
# 4                  RECRUITING             nan  2022-09-13
# ...                       ...             ...         ...
# 204670              COMPLETED             nan     2012-03
# 204671  ACTIVE_NOT_RECRUITING             nan     2016-09
# 204672              COMPLETED             nan  2021-08-06
# 204673             RECRUITING             nan  2024-08-14
# 204674              COMPLETED             nan     2012-04
#
#        PrimaryCompletionDate CompletionDate StudyFirstSubmitDate  \
# 0                    2011-12        2011-12           2011-02-24
# 1                 2024-12-30     2024-12-30           2020-07-24
# 2                 2021-04-28     2022-02-23           2019-09-10
# 3                    2011-06        2011-06           2010-08-12
# 4                 2026-06-30     2026-06-30           2021-11-16
# ...                      ...            ...                  ...
# 204670               2012-04        2012-05           2012-05-08
# 204671            2022-12-22     2026-04-30           2016-09-14
# 204672            2023-06-10     2023-06-10           2021-06-30
# 204673            2027-01-14     2027-03-14           2024-08-23
# 204674               2014-09        2014-10           2013-01-04
#
#        LastUpdateSubmitDate  ...  Sex MinimumAge MaximumAge  \
# 0                2011-08-04  ...  ALL      1 Day   2 Months
# 1                2025-01-07  ...  ALL   18 Years        nan
# 2                2025-02-10  ...  ALL   18 Years   75 Years
# 3                2014-04-15  ...  ALL   18 Years        nan
# 4                2024-12-17  ...  ALL   20 Years        nan
# ...                     ...  ...  ...        ...        ...
# 204670           2012-05-10  ...  ALL   18 Years   60 Years
# 204671           2024-11-18  ...  ALL   18 Years        nan
# 204672           2024-02-05  ...  ALL   18 Years   55 Years
# 204673           2025-09-09  ...  ALL   12 Years        nan
# 204674           2018-04-16  ...  ALL   18 Years   70 Years
#
#                                           LocationCountry  \
# 0                       [{"country": "Turkey (Türkiye)"}]
# 1       [{"country": "Germany"}, {"country": "Germany"...
# 2       [{"country": "United States"}, {"country": "Un...
# 3                                  [{"country": "Spain"}]
# 4       [{"country": "Taiwan"}, {"country": "Taiwan"},...
# ...                                                   ...
# 204670                             [{"country": "Chile"}]
# 204671  [{"country": "Denmark"}, {"country": "Finland"...
# 204672  [{"country": "United States"}, {"country": "Un...
# 204673  [{"country": "United States"}, {"country": "Un...
# 204674       [{"country": "China"}, {"country": "China"}]
#
#                                         ConditionMeshTerm HasResults  \
# 0                [{"term": "Enterocolitis, Necrotizing"}]      False
# 1                       [{"term": "Neoplasm Metastasis"}]      False
# 2                        [{"term": "Dermatitis, Atopic"}]       True
# 3       [{"term": "Alzheimer Disease"}, {"term": "Deme...       True
# 4                 [{"term": "Carcinoma, Hepatocellular"}]      False
# ...                                                   ...        ...
# 204670                              [{"term": "Obesity"}]      False
# 204671                 [{"term": "Pancreatic Neoplasms"}]      False
# 204672                             [{"term": "COVID-19"}]      False
# 204673  [{"term": "Neoplasm Metastasis"}, {"term": "Ne...      False
# 204674                 [{"term": "Colorectal Neoplasms"}]      False
#
#                                      InterventionMeshTerm  \
# 0                                                     nan
# 1       [{"term": "Vemurafenib"}, {"term": "cobimetini...
# 2                                [{"term": "spesolimab"}]
# 3                               [{"term": "Galantamine"}]
# 4                            [{"term": "Ethiodized Oil"}]
# ...                                                   ...
# 204670                             [{"term": "Propofol"}]
# 204671  [{"term": "Fluorouracil"}, {"term": "Oxaliplat...
# 204672              [{"term": "CVXGA1 COVID-19 vaccine"}]
# 204673                                                nan
# 204674                            [{"term": "famitinib"}]
#
#                                                WhyStopped IPDSharing  \
# 0                                                     nan        nan
# 1                                                     nan        nan
# 2                                        Sponsor decision         NO
# 3       The recruitment rate was very low (one screeni...        nan
# 4                                                     nan        nan
# ...                                                   ...        ...
# 204670                                                nan        nan
# 204671                                                nan         NO
# 204672                                                nan        YES
# 204673                                                nan        nan
# 204674                                                nan        nan
#
#                                          CollaboratorName
# 0                                                     nan
# 1                                                     nan
# 2                                                     nan
# 3                                                     nan
# 4                                                     nan
# ...                                                   ...
# 204670                                                nan
# 204671  [{"name": "St. Olavs Hospital"}, {"name": "Hau...
# 204672                                                nan
# 204673                                                nan
# 204674  [{"name": "Peking University Cancer Hospital &...
#
# [204675 rows x 38 columns]

# %%
# Guardamos el archivo una vez limpiado, que se usará en el proximo paso

out_path = CLEAN_DIR / f"clinicaltrials_clean.csv"

df_clean.to_csv(out_path, index=False)

print("Dataset guardado en:")
out_path
# Out:
# Dataset guardado en:
# WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/clean/clinicaltrials_clean.csv')

# %% [markdown]
# - Se ha cargado correctamente el fichero RAW más reciente.
#
# - Se observa la estructura inicial de los datos tal y como vienen de la API.
#
# - Se ha realizado una limpieza:
#   - Normalización de nombres de columnas
#   - Conversión inicial de columnas de fechas
#   - Eliminación de formatos no estándar
#
# El resto del análisis se basará en el archivo generado en `data/clean/`:
# - `clinicaltrials_clean.csv`
