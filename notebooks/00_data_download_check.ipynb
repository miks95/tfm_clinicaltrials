# %% [markdown]
# # 00 — Descarga de datos y validación de datos raw
# Descarga inicial de los datos desde la API de ClinicalTrials.gov (https://clinicaltrials.gov/data-api/api) utilizando el script `src/download_clinicaltrials.py`.
#
# - Verifica que el fichero con datos RAW se ha generado correctamente.
# - Carga una muestra para inspeccionar la estructura y coherencia.
# - Guarda el dataset para el Notebook 01 (EDA).
#
# **Nota: Este notebook solo debe ejecutarse cuando se desea descargar datos.** Idealmente ejecutar el notebook una sola vez, guardar el snapshot en `data/raw/`, y usar siempre ese archivo en el resto de notebooks.

# %%
from pathlib import Path
import pandas as pd
import datetime

import json

# Buscar cual es la ruta del proyecto, un nivel mas arriba que la ruta del notebook

PROJECT_ROOT = Path.cwd().parent
print("Proyecto cargado desde:", PROJECT_ROOT)

# Creamos las carpeta RAW y CLEAN para guardar los datos

RAW_DIR = PROJECT_ROOT / "data" / "raw"
CLEAN_DIR = PROJECT_ROOT / "data" / "clean"

RAW_DIR.mkdir(parents=True, exist_ok=True)
CLEAN_DIR.mkdir(parents=True, exist_ok=True)

print("\nCarpeta datos RAW:", RAW_DIR)
print("Carpeta datos CLEAN:", CLEAN_DIR)
# Out:
# Proyecto cargado desde: C:\Users\Administrador\Documents\tfm_clinicaltrials
#
# Carpeta datos RAW: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# Carpeta datos CLEAN: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\clean

# %%
# Ejecución del script de descarga

# %cd ..
# %run -m src.download_clinicaltrials 200
# Out:
# C:\Users\Administrador\Documents\tfm_clinicaltrials
# Descargando 200 filas
# Descargando todos los campos por defecto
# Descargando ensayos: 100%|██████████| 200/200 [00:01<00:00, 119.40ensayos/s]
# Alcanzado el número máximo de ensayos=200, parando la ejecución.
# Se han descargado 200 ensayos.
# Datos RAW guardados en: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251208_182649.csv

# %%
raw_files = list(RAW_DIR.glob("clinicaltrials_*.csv"))
raw_files_sorted = sorted(raw_files, key=lambda x: x.stat().st_mtime, reverse=True)

print("\nFicheros RAW mas recientes", RAW_DIR)

raw_files_sorted[:5]
# Out:
# Ficheros RAW mas recientes C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# [WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_182649.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_182300.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_181025.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_143015.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_141314.csv')]

# %%
if not raw_files_sorted:
    raise FileNotFoundError("No hay ficheros en data/raw/. Necesario ejecutar el script de descarga.")

raw_file = raw_files_sorted[0]
print("Se usa el fichero mas reciente:", raw_file)

df_raw_check = pd.read_csv(raw_file, low_memory=False)
df_raw_check.head(20)
# Out:
# Se usa el fichero mas reciente: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251208_182649.csv
#    protocolSection.identificationModule.nctId  \
# 0                                 NCT03034993
# 1                                 NCT06822621
# 2                                 NCT04551521
# 3                                 NCT04086121
# 4                                 NCT04538521
# 5                                 NCT07103421
# 6                                 NCT06684821
# 7                                 NCT05435014
# 8                                 NCT02497716
# 9                                 NCT06236516
# 10                                NCT05833906
# 11                                NCT05194306
# 12                                NCT05664906
# 13                                NCT07208604
# 14                                NCT02866604
# 15                                NCT04019704
# 16                                NCT02978404
# 17                                NCT03945552
# 18                                NCT06736587
# 19                                NCT05849493
#
#    protocolSection.identificationModule.orgStudyIdInfo.id  \
# 0                                             H-35967
# 1                                   106/2023_16.11.23
# 2                                        NCT-PMO-1602
# 3                                           1368-0037
# 4                                          NiaMIT_002
# 5                            Tishreen U _ periodontic
# 6                                    36264PR903/10/24
# 7                                       TACE-OHEP-001
# 8                                               17992
# 9                                           202401015
# 10                                 COSMOS-21-RegenT-1
# 11                                            CIP001A
# 12                                      CM Rinse_OMRT
# 13                                            TEC-006
# 14                                        201510-1766
# 15                                     AXS-05-MDD-301
# 16                                             16.206
# 17                                           18-01347
# 18                                    DW_DWP212525101
# 19                                  2022-02380-01-RCT
#
#    protocolSection.identificationModule.secondaryIdInfos  \
# 0   [{"id": "catalyst grant", "type": "OTHER", "do...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [{"id": "2015-000962-76", "type": "EUDRACT_NUM...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  [{"id": "OZM-080", "type": "OTHER", "domain": ...
# 17  [{"id": "R01HD096909-01A1", "type": "NIH", "li...
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.identificationModule.organization.fullName  \
# 0                                   Boston University
# 1                                Harokopio University
# 2                       German Cancer Research Center
# 3                                Boehringer Ingelheim
# 4                              University of Helsinki
# 5                                 Tishreen University
# 6                                    Tanta University
# 7                              T-ACE Medical Co., Ltd
# 8                                               Bayer
# 9            Washington University School of Medicine
# 10                                     CK Regeon Inc.
# 11                            Advanced Life Solutions
# 12                    Chinese University of Hong Kong
# 13                                      TECLens, Inc.
# 14                               University of Malaya
# 15                          Axsome Therapeutics, Inc.
# 16  Centre hospitalier de l'Université de Montréal...
# 17                                 NYU Langone Health
# 18                   Daewoong Pharmaceutical Co. LTD.
# 19                              Karolinska Institutet
#
#    protocolSection.identificationModule.organization.class  \
# 0                                               OTHER
# 1                                               OTHER
# 2                                               OTHER
# 3                                            INDUSTRY
# 4                                               OTHER
# 5                                               OTHER
# 6                                               OTHER
# 7                                            INDUSTRY
# 8                                            INDUSTRY
# 9                                               OTHER
# 10                                           INDUSTRY
# 11                                           INDUSTRY
# 12                                              OTHER
# 13                                           INDUSTRY
# 14                                              OTHER
# 15                                           INDUSTRY
# 16                                              OTHER
# 17                                              OTHER
# 18                                           INDUSTRY
# 19                                              OTHER
#
#       protocolSection.identificationModule.briefTitle  \
# 0   Self-Management Using Text Messaging in a Home...
# 1   Functional Cereal Products and Contribution to...
# 2              CRAFT: The NCT-PMO-1602 Phase II Trial
# 3   A Study to Test the Long-term Safety of BI 655...
# 4   NiaMIT Continuation With Early-stage Mitochond...
# 5   Impact of Non Surgical Periodontal Therapy on ...
# 6   Epidural Neuroplasty Using Racz Catheter Durin...
# 7   T-ACE Oil by TAE/TACE in Patients With Hepatoc...
# 8   Phase I Study on Rivaroxaban Granules for Oral...
# 9   One Fraction Simulation-Free Treatment With CT...
# 10  Safety, Tolerability, and Pharmacokinetic Eval...
# 11            PERTRIAL - Perla® Preservation Solution
# 12  Evaluating Chinese Medicine Oral Rinse for Irr...
# 13  Open Label, Multi-center, Phase I Study of TEC...
# 14  Comparison of an Isotonic Balanced Fluid, Ster...
# 15  A Trial of AXS-05 in Patients With Major Depre...
# 16  Combining Radiosurgery and Nivolumab in the Tr...
# 17               Pediatric Parenting Support in Flint
# 18  A Randomized, Double-blind, Placebo-controlled...
# 19  Effects and Mechanisms of Change of Internet D...
#
#    protocolSection.identificationModule.officialTitle  \
# 0   Improving Self-Management of Chronic Condition...
# 1   Functional Cereal Products and Contribution to...
# 2   Continuous ReAssessment With Flexible ExTensio...
# 3   An Open Label Extension Study to Assess the Lo...
# 4   NiaMIT (NiaMIT_0001) Continuation for Early-st...
# 5   Effect of Non-Surgical Periodontal Therapy on ...
# 6   Analgesic Efficacy of Epidural Neuroplasty Usi...
# 7   Phase I/II Randomized, Double-Blind, First-in-...
# 8   Single-dose Study Testing Rivaroxaban Granules...
# 9   One Fraction Simulation-Free Treatment With CT...
# 10  A Randomized, Single-blind, Placebo-controlled...
# 11  Evaluation of the Safety and Performance of Pe...
# 12  Evaluating Efficacy and Safety of Chinese Medi...
# 13  Open Label, Multi-center, Phase I Study of TEC...
# 14  Comparison of an Isotonic Balanced Fluid, Ster...
# 15  AXS-05-MDD-301: A Randomized, Double-Blind, Pl...
# 16  A Phase II, Multi-centre Study, of Combining R...
# 17  Universal Strengths-Based Parenting Support in...
# 18  A Randomized, Double-blind, Placebo-controlled...
# 19  Effects and Mechanisms of Change of Internet D...
#
#    protocolSection.statusModule.statusVerifiedDate  \
# 0                                          2019-05
# 1                                          2025-02
# 2                                          2024-05
# 3                                          2025-02
# 4                                          2021-01
# 5                                          2025-08
# 6                                          2025-04
# 7                                          2024-11
# 8                                          2019-04
# 9                                          2025-08
# 10                                         2024-01
# 11                                         2022-01
# 12                                         2022-12
# 13                                         2025-09
# 14                                         2016-10
# 15                                         2022-09
# 16                                         2024-06
# 17                                         2025-12
# 18                                         2024-12
# 19                                         2025-08
#
#    protocolSection.statusModule.overallStatus  \
# 0                                   COMPLETED
# 1                     ENROLLING_BY_INVITATION
# 2                                   COMPLETED
# 3                                  TERMINATED
# 4                                   COMPLETED
# 5                                   COMPLETED
# 6                                   COMPLETED
# 7                                  RECRUITING
# 8                                   COMPLETED
# 9                                   COMPLETED
# 10                                  COMPLETED
# 11                                  COMPLETED
# 12                                    UNKNOWN
# 13                         NOT_YET_RECRUITING
# 14                                    UNKNOWN
# 15                                  COMPLETED
# 16                                  COMPLETED
# 17                      ACTIVE_NOT_RECRUITING
# 18                                 RECRUITING
# 19                      ACTIVE_NOT_RECRUITING
#
#    protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess  ...  \
# 0                                               False                 ...
# 1                                               False                 ...
# 2                                               False                 ...
# 3                                               False                 ...
# 4                                               False                 ...
# 5                                               False                 ...
# 6                                               False                 ...
# 7                                               False                 ...
# 8                                               False                 ...
# 9                                               False                 ...
# 10                                              False                 ...
# 11                                              False                 ...
# 12                                              False                 ...
# 13                                              False                 ...
# 14                                              False                 ...
# 15                                              False                 ...
# 16                                              False                 ...
# 17                                              False                 ...
# 18                                              False                 ...
# 19                                              False                 ...
#
#    protocolSection.ipdSharingStatementModule.url  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
#
#    protocolSection.identificationModule.orgStudyIdInfo.type  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.identificationModule.orgStudyIdInfo.link  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.date  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    derivedSection.miscInfoModule.submissionTracking.firstMcpInfo.postDateStruct.type  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.oversightModule.isUnapprovedDevice  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.referencesModule.availIpds  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
#
#    resultsSection.moreInfoModule.pointOfContact.phoneExt  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.statusModule.expandedAccessInfo.nctId  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    protocolSection.statusModule.expandedAccessInfo.statusForNctId
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 130 columns]

# %%
print("Shape:", df_raw_check.shape)
print("\nColumnas:")
print(df_raw_check.columns.tolist())
# Out:
# Shape: (200, 130)
#
# Columnas:
# ['protocolSection.identificationModule.nctId', 'protocolSection.identificationModule.orgStudyIdInfo.id', 'protocolSection.identificationModule.secondaryIdInfos', 'protocolSection.identificationModule.organization.fullName', 'protocolSection.identificationModule.organization.class', 'protocolSection.identificationModule.briefTitle', 'protocolSection.identificationModule.officialTitle', 'protocolSection.statusModule.statusVerifiedDate', 'protocolSection.statusModule.overallStatus', 'protocolSection.statusModule.expandedAccessInfo.hasExpandedAccess', 'protocolSection.statusModule.startDateStruct.date', 'protocolSection.statusModule.startDateStruct.type', 'protocolSection.statusModule.primaryCompletionDateStruct.date', 'protocolSection.statusModule.primaryCompletionDateStruct.type', 'protocolSection.statusModule.completionDateStruct.date', 'protocolSection.statusModule.completionDateStruct.type', 'protocolSection.statusModule.studyFirstSubmitDate', 'protocolSection.statusModule.studyFirstSubmitQcDate', 'protocolSection.statusModule.studyFirstPostDateStruct.date', 'protocolSection.statusModule.studyFirstPostDateStruct.type', 'protocolSection.statusModule.lastUpdateSubmitDate', 'protocolSection.statusModule.lastUpdatePostDateStruct.date', 'protocolSection.statusModule.lastUpdatePostDateStruct.type', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.type', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.investigatorFullName', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.investigatorTitle', 'protocolSection.sponsorCollaboratorsModule.responsibleParty.investigatorAffiliation', 'protocolSection.sponsorCollaboratorsModule.leadSponsor.name', 'protocolSection.sponsorCollaboratorsModule.leadSponsor.class', 'protocolSection.sponsorCollaboratorsModule.collaborators', 'protocolSection.oversightModule.oversightHasDmc', 'protocolSection.oversightModule.isFdaRegulatedDrug', 'protocolSection.oversightModule.isFdaRegulatedDevice', 'protocolSection.descriptionModule.briefSummary', 'protocolSection.descriptionModule.detailedDescription', 'protocolSection.conditionsModule.conditions', 'protocolSection.conditionsModule.keywords', 'protocolSection.designModule.studyType', 'protocolSection.designModule.phases', 'protocolSection.designModule.designInfo.allocation', 'protocolSection.designModule.designInfo.interventionModel', 'protocolSection.designModule.designInfo.primaryPurpose', 'protocolSection.designModule.designInfo.maskingInfo.masking', 'protocolSection.designModule.enrollmentInfo.count', 'protocolSection.designModule.enrollmentInfo.type', 'protocolSection.armsInterventionsModule.armGroups', 'protocolSection.armsInterventionsModule.interventions', 'protocolSection.outcomesModule.primaryOutcomes', 'protocolSection.outcomesModule.secondaryOutcomes', 'protocolSection.eligibilityModule.eligibilityCriteria', 'protocolSection.eligibilityModule.healthyVolunteers', 'protocolSection.eligibilityModule.sex', 'protocolSection.eligibilityModule.minimumAge', 'protocolSection.eligibilityModule.stdAges', 'protocolSection.contactsLocationsModule.overallOfficials', 'protocolSection.contactsLocationsModule.locations', 'protocolSection.referencesModule.references', 'protocolSection.ipdSharingStatementModule.ipdSharing', 'derivedSection.miscInfoModule.versionHolder', 'derivedSection.conditionBrowseModule.meshes', 'derivedSection.conditionBrowseModule.ancestors', 'hasResults', 'protocolSection.designModule.designInfo.maskingInfo.whoMasked', 'protocolSection.eligibilityModule.maximumAge', 'derivedSection.interventionBrowseModule.meshes', 'derivedSection.interventionBrowseModule.ancestors', 'protocolSection.statusModule.whyStopped', 'protocolSection.statusModule.resultsFirstSubmitDate', 'protocolSection.statusModule.resultsFirstSubmitQcDate', 'protocolSection.statusModule.resultsFirstPostDateStruct.date', 'protocolSection.statusModule.resultsFirstPostDateStruct.type', 'protocolSection.referencesModule.seeAlsoLinks', 'protocolSection ...

# %%
lista_columnas = [
    "protocolSection.identificationModule.nctId",
    "protocolSection.identificationModule.briefTitle",
    "protocolSection.identificationModule.officialTitle",
    "protocolSection.statusModule.overallStatus",
    "protocolSection.statusModule.lastKnownStatus",
    "protocolSection.statusModule.whyStopped",
    "protocolSection.statusModule.startDateStruct.date",
    "protocolSection.statusModule.primaryCompletionDateStruct.date",
    "protocolSection.statusModule.completionDateStruct.date",
    "protocolSection.designModule.studyType",
    "protocolSection.designModule.phases",
    "protocolSection.designModule.enrollmentInfo.count",
    "protocolSection.designModule.designInfo.allocation",
    "protocolSection.designModule.designInfo.interventionModel",
    "protocolSection.designModule.designInfo.primaryPurpose",
    "protocolSection.designModule.designInfo.maskingInfo.masking",
    "protocolSection.designModule.designInfo.maskingInfo.whoMasked",
    "protocolSection.conditionsModule.conditions",
    "protocolSection.conditionsModule.keywords",
    "protocolSection.contactsLocationsModule.locations",
    "protocolSection.armsInterventionsModule.interventions",
    "protocolSection.outcomesModule.primaryOutcomes",
    "protocolSection.outcomesModule.secondaryOutcomes",
    "protocolSection.descriptionModule.briefSummary",
    "protocolSection.sponsorCollaboratorsModule.leadSponsor.name",
    "protocolSection.sponsorCollaboratorsModule.leadSponsor.class",
    "protocolSection.sponsorCollaboratorsModule.collaborators",
    "protocolSection.eligibilityModule.minimumAge",
    "protocolSection.eligibilityModule.maximumAge",
    "protocolSection.eligibilityModule.sex",
    "protocolSection.eligibilityModule.healthyVolunteers",
    "protocolSection.eligibilityModule.eligibilityCriteria",
    "derivedSection.conditionBrowseModule.meshes",
    "derivedSection.interventionBrowseModule.meshes",
    "hasResults",
    "protocolSection.statusModule.lastUpdateSubmitDate",
    "protocolSection.statusModule.studyFirstSubmitDate",
    "protocolSection.ipdSharingStatementModule.ipdSharing",
]

# Observamos en https://clinicaltrials.gov/data-api/about-api/study-data-structure cuales son los nombres de los campos que se aceptan:

fields_api = [
    "NCTId","BriefTitle","OfficialTitle",
    "OverallStatus","LastKnownStatus","WhyStopped",
    "StartDate","PrimaryCompletionDate","CompletionDate",
    "StudyType","Phase","EnrollmentCount",
    "DesignAllocation",
    "DesignInterventionModel ",
    "DesignPrimaryPurpose ",
    "DesignMasking","DesignWhoMasked",
    "Condition","Keyword",
    "LocationCountry",
    "InterventionType","InterventionName",
    "PrimaryOutcomeMeasure","SecondaryOutcomeMeasure",
    "BriefSummary",
    "LeadSponsorName","LeadSponsorClass","CollaboratorName",
    "MinimumAge","MaximumAge","Sex","HealthyVolunteers",
    "EligibilityCriteria",
    "ConditionMeshTerm","InterventionMeshTerm",
    "HasResults",
    "LastUpdateSubmitDate","StudyFirstSubmitDate",
    "IPDSharing"
]

cols_str = " ".join(fields_api)

# %%
# %run -m src.download_clinicaltrials 300000 $cols_str
# Out:
# Descargando 300000 filas
# Usando columnas: ['NCTId', 'BriefTitle', 'OfficialTitle', 'OverallStatus', 'LastKnownStatus', 'WhyStopped', 'StartDate', 'PrimaryCompletionDate', 'CompletionDate', 'StudyType', 'Phase', 'EnrollmentCount', 'DesignAllocation', 'DesignInterventionModel', 'DesignPrimaryPurpose', 'DesignMasking', 'DesignWhoMasked', 'Condition', 'Keyword', 'LocationCountry', 'InterventionType', 'InterventionName', 'PrimaryOutcomeMeasure', 'SecondaryOutcomeMeasure', 'BriefSummary', 'LeadSponsorName', 'LeadSponsorClass', 'CollaboratorName', 'MinimumAge', 'MaximumAge', 'Sex', 'HealthyVolunteers', 'EligibilityCriteria', 'ConditionMeshTerm', 'InterventionMeshTerm', 'HasResults', 'LastUpdateSubmitDate', 'StudyFirstSubmitDate', 'IPDSharing']
# Descargando ensayos:  91%|█████████ | 273095/300000 [07:39<00:45, 594.90ensayos/s]
# No existe nextPageToken, parando la ejecución.
# Se han descargado 273095 ensayos.
# Datos RAW guardados en: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251208_183431.csv

# %%
raw_files = list(RAW_DIR.glob("clinicaltrials_*.csv"))
raw_files_sorted = sorted(raw_files, key=lambda x: x.stat().st_mtime, reverse=True)

print("\nFicheros RAW mas recientes", RAW_DIR)

raw_files_sorted[:5]
# Out:
# Ficheros RAW mas recientes C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw
# [WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_183431.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_182649.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_182300.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_181025.csv'),
#  WindowsPath('C:/Users/Administrador/Documents/tfm_clinicaltrials/data/raw/clinicaltrials_raw_20251208_143015.csv')]

# %%
if not raw_files_sorted:
    raise FileNotFoundError("No hay ficheros en data/raw/. Necesario ejecutar el script de descarga.")

raw_file = raw_files_sorted[0]
print("Se usa el fichero mas reciente:", raw_file)

df_raw = pd.read_csv(raw_file, low_memory=False)
df_raw.head()
# Out:
# Se usa el fichero mas reciente: C:\Users\Administrador\Documents\tfm_clinicaltrials\data\raw\clinicaltrials_raw_20251208_183431.csv
#   protocolSection.identificationModule.nctId  \
# 0                                NCT03034993
# 1                                NCT06822621
# 2                                NCT04551521
# 3                                NCT04086121
# 4                                NCT04538521
#
#      protocolSection.identificationModule.briefTitle  \
# 0  Self-Management Using Text Messaging in a Home...
# 1  Functional Cereal Products and Contribution to...
# 2             CRAFT: The NCT-PMO-1602 Phase II Trial
# 3  A Study to Test the Long-term Safety of BI 655...
# 4  NiaMIT Continuation With Early-stage Mitochond...
#
#   protocolSection.identificationModule.officialTitle  \
# 0  Improving Self-Management of Chronic Condition...
# 1  Functional Cereal Products and Contribution to...
# 2  Continuous ReAssessment With Flexible ExTensio...
# 3  An Open Label Extension Study to Assess the Lo...
# 4  NiaMIT (NiaMIT_0001) Continuation for Early-st...
#
#   protocolSection.statusModule.overallStatus  \
# 0                                  COMPLETED
# 1                    ENROLLING_BY_INVITATION
# 2                                  COMPLETED
# 3                                 TERMINATED
# 4                                  COMPLETED
#
#   protocolSection.statusModule.startDateStruct.date  \
# 0                                        2017-07-21
# 1                                        2024-09-02
# 2                                        2021-10-13
# 3                                        2019-09-24
# 4                                        2019-02-11
#
#   protocolSection.statusModule.primaryCompletionDateStruct.date  \
# 0                                         2018-12-30
# 1                                         2025-06-30
# 2                                         2024-12-30
# 3                                         2021-04-28
# 4                                         2020-09-18
#
#   protocolSection.statusModule.completionDateStruct.date  \
# 0                                         2019-04-30
# 1                                         2025-09-30
# 2                                         2024-12-30
# 3                                         2022-02-23
# 4                                         2020-09-18
#
#   protocolSection.statusModule.studyFirstSubmitDate  \
# 0                                        2017-01-26
# 1                                        2025-01-31
# 2                                        2020-07-24
# 3                                        2019-09-10
# 4                                        2020-08-29
#
#   protocolSection.statusModule.lastUpdateSubmitDate  \
# 0                                        2019-05-01
# 1                                        2025-02-06
# 2                                        2025-01-07
# 3                                        2025-02-10
# 4                                        2021-01-21
#
#   protocolSection.sponsorCollaboratorsModule.leadSponsor.name  ...  \
# 0                                  Boston University           ...
# 1                               Harokopio University           ...
# 2                      German Cancer Research Center           ...
# 3                               Boehringer Ingelheim           ...
# 4                             University of Helsinki           ...
#
#   protocolSection.eligibilityModule.minimumAge  \
# 0                                     18 Years
# 1                                     25 Years
# 2                                     18 Years
# 3                                     18 Years
# 4                                     17 Years
#
#    protocolSection.contactsLocationsModule.locations  \
# 0                     [{"country": "United States"}]
# 1                            [{"country": "Greece"}]
# 2  [{"country": "Germany"}, {"country": "Germany"...
# 3  [{"country": "United States"}, {"country": "Un...
# 4                           [{"country": "Finland"}]
#
#   protocolSection.ipdSharingStatementModule.ipdSharing  \
# 0                                                 NO
# 1                                                 NO
# 2                                                NaN
# 3                                                 NO
# 4                                                 NO
#
#          derivedSection.conditionBrowseModule.meshes hasResults  \
# 0  [{"term": "Chronic Disease"}, {"term": "Medica...      False
# 1  [{"term": "Hypercholesterolemia"}, {"term": "O...      False
# 2                  [{"term": "Neoplasm Metastasis"}]      False
# 3                   [{"term": "Dermatitis, Atopic"}]       True
# 4             [{"term": "Mitochondrial Myopathies"}]      False
#
#   protocolSection.designModule.designInfo.maskingInfo.whoMasked  \
# 0                                                NaN
# 1                                    ["PARTICIPANT"]
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   protocolSection.eligibilityModule.maximumAge  \
# 0                                          NaN
# 1                                     60 Years
# 2                                          NaN
# 3                                     75 Years
# 4                                          NaN
#
#       derivedSection.interventionBrowseModule.meshes  \
# 0                                                NaN
# 1                              [{"term": "Methods"}]
# 2  [{"term": "Vemurafenib"}, {"term": "cobimetini...
# 3                           [{"term": "spesolimab"}]
# 4                               [{"term": "Niacin"}]
#
#   protocolSection.statusModule.whyStopped  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                        Sponsor decision
# 4                                     NaN
#
#   protocolSection.statusModule.lastKnownStatus
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 38 columns]

# %%
df_clean = df_raw.copy()

df_clean.columns = (df_clean.columns.str.lower())

rename_map = {
    "protocolsection.identificationmodule.nctid": "nct_id",
    "protocolsection.identificationmodule.brieftitle": "brief_title",
    "protocolsection.identificationmodule.officialtitle": "official_title",
    "protocolsection.sponsorcollaboratorsmodule.leadsponsor.name": "lead_sponsor_name",
    "protocolsection.sponsorcollaboratorsmodule.leadsponsor.class": "lead_sponsor_class",
    "protocolsection.sponsorcollaboratorsmodule.collaborators": "collaborators",
    "protocolsection.statusmodule.overallstatus": "overall_status",
    "protocolsection.statusmodule.lastknownstatus": "last_known_status",
    "protocolsection.statusmodule.whystopped": "why_stopped",
    "protocolsection.statusmodule.startdatestruct.date": "start_date",
    "protocolsection.statusmodule.primarycompletiondatestruct.date": "primary_completion_date",
    "protocolsection.statusmodule.completiondatestruct.date": "completion_date",
    "protocolsection.statusmodule.lastupdatesubmitdate": "last_update_submit_date",
    "protocolsection.statusmodule.studyfirstsubmitdate": "study_first_submit_date",
    "protocolsection.designmodule.studytype": "study_type",
    "protocolsection.designmodule.phases": "phases",
    "protocolsection.designmodule.enrollmentinfo.count": "enrollment_count",
    "protocolsection.designmodule.enrollmentinfo.type": "enrollment_type",
    "protocolsection.designmodule.designinfo.allocation": "allocation",
    "protocolsection.designmodule.designinfo.interventionmodel": "intervention_model",
    "protocolsection.designmodule.designinfo.primarypurpose": "primary_purpose",
    "protocolsection.designmodule.designinfo.maskinginfo.masking": "masking",
    "protocolsection.designmodule.designinfo.maskinginfo.whomasked": "who_masked",
    "protocolsection.conditionsmodule.conditions": "conditions",
    "protocolsection.conditionsmodule.keywords": "keywords",
    "protocolsection.contactslocationsmodule.locations": "locations",
    "protocolsection.armsinterventionsmodule.interventions": "interventions",
    "protocolsection.outcomesmodule.primaryoutcomes": "primary_outcomes",
    "protocolsection.outcomesmodule.secondaryoutcomes": "secondary_outcomes",
    "protocolsection.descriptionmodule.briefsummary": "brief_summary",
    "protocolsection.eligibilitymodule.minimumage": "minimum_age",
    "protocolsection.eligibilitymodule.maximumage": "maximum_age",
    "protocolsection.eligibilitymodule.sex": "sex",
    "protocolsection.eligibilitymodule.healthyvolunteers": "healthy_volunteers",
    "protocolsection.eligibilitymodule.eligibilitycriteria": "eligibility_criteria",
    "derivedsection.conditionbrowsemodule.meshes": "condition_mesh_terms",
    "derivedsection.interventionbrowsemodule.meshes": "intervention_mesh_terms",
    "hasresults": "has_results",
    "protocolsection.ipdsharingstatementmodule.ipdsharing": "ipd_sharing",
}


df_clean = df_clean.rename(columns=rename_map)
  
# Convertir fechas
for col in ["start_date", "primary_completion_date", "completion_date", "last_update_submit_date", "study_first_submit_date"]:
    if col in df_clean.columns:
        df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")

df_clean["duration_days"] = (df_clean["completion_date"] - df_clean["start_date"]).dt.days

df_clean = df_clean.apply(lambda col: 
    col.astype(str)
       .str.replace("\n", " ", regex=False)
       .str.replace("\r", " ", regex=False)
    if col.dtype == "object" else col
)


df_clean
# Out:
#              nct_id                                        brief_title  \
# 0       NCT03034993  Self-Management Using Text Messaging in a Home...
# 1       NCT06822621  Functional Cereal Products and Contribution to...
# 2       NCT04551521             CRAFT: The NCT-PMO-1602 Phase II Trial
# 3       NCT04086121  A Study to Test the Long-term Safety of BI 655...
# 4       NCT04538521  NiaMIT Continuation With Early-stage Mitochond...
# ...             ...                                                ...
# 273090  NCT05253287    Growth Hormone in Decompensated Liver Cirrhosis
# 273091  NCT02919787       Nordic Pancreatic Cancer Trial (NorPACT) - 1
# 273092  NCT04954287  Phase 1 Study of Intranasal PIV5 COVID-19 Vacc...
# 273093  NCT06577987  Safety/Efficacy Study of CID-078 in Patients W...
# 273094  NCT04631887  The Delivery of "Doing What Matters in Times o...
#
#                                            official_title  \
# 0       Improving Self-Management of Chronic Condition...
# 1       Functional Cereal Products and Contribution to...
# 2       Continuous ReAssessment With Flexible ExTensio...
# 3       An Open Label Extension Study to Assess the Lo...
# 4       NiaMIT (NiaMIT_0001) Continuation for Early-st...
# ...                                                   ...
# 273090  Impact of Repurposed Growth Hormone Treatment ...
# 273091  Nordic Multicentre Un-blinded Phase II Randomi...
# 273092  A Phase 1 Open-Label, Dose-Ranging Trial to Ev...
# 273093  A Phase 1, Open-Label, Multicenter Study to Ev...
# 273094  The Feasibility Study of The Delivery of The B...
#
#                  overall_status start_date primary_completion_date  \
# 0                     COMPLETED 2017-07-21              2018-12-30
# 1       ENROLLING_BY_INVITATION 2024-09-02              2025-06-30
# 2                     COMPLETED 2021-10-13              2024-12-30
# 3                    TERMINATED 2019-09-24              2021-04-28
# 4                     COMPLETED 2019-02-11              2020-09-18
# ...                         ...        ...                     ...
# 273090                COMPLETED 2022-02-01              2024-12-31
# 273091    ACTIVE_NOT_RECRUITING        NaT              2022-12-22
# 273092                COMPLETED 2021-08-06              2023-06-10
# 273093               RECRUITING 2024-08-14              2027-01-14
# 273094                COMPLETED 2020-11-09              2021-01-29
#
#        completion_date study_first_submit_date last_update_submit_date  \
# 0           2019-04-30              2017-01-26              2019-05-01
# 1           2025-09-30              2025-01-31              2025-02-06
# 2           2024-12-30              2020-07-24              2025-01-07
# 3           2022-02-23              2019-09-10              2025-02-10
# 4           2020-09-18              2020-08-29              2021-01-21
# ...                ...                     ...                     ...
# 273090      2024-12-31              2021-12-15              2025-11-27
# 273091      2026-04-30              2016-09-14              2024-11-18
# 273092      2023-06-10              2021-06-30              2024-02-05
# 273093      2027-03-14              2024-08-23              2025-09-09
# 273094      2021-01-29              2020-11-07              2021-02-19
#
#                                         lead_sponsor_name  ...  \
# 0                                       Boston University  ...
# 1                                    Harokopio University  ...
# 2                           German Cancer Research Center  ...
# 3                                    Boehringer Ingelheim  ...
# 4                                  University of Helsinki  ...
# ...                                                   ...  ...
# 273090  Post Graduate Institute of Medical Education a...  ...
# 273091                           Oslo University Hospital  ...
# 273092                                        CyanVac LLC  ...
# 273093                                      Circle Pharma  ...
# 273094                                     Koç University  ...
#
#                                                 locations ipd_sharing  \
# 0                          [{"country": "United States"}]          NO
# 1                                 [{"country": "Greece"}]          NO
# 2       [{"country": "Germany"}, {"country": "Germany"...         nan
# 3       [{"country": "United States"}, {"country": "Un...          NO
# 4                                [{"country": "Finland"}]          NO
# ...                                                   ...         ...
# 273090                             [{"country": "India"}]          NO
# 273091  [{"country": "Denmark"}, {"country": "Finland"...          NO
# 273092  [{"country": "United States"}, {"country": "Un...         YES
# 273093  [{"country": "United States"}, {"country": "Un...         nan
# 273094                  [{"country": "Turkey (Türkiye)"}]          NO
#
#                                      condition_mesh_terms has_results  \
# 0       [{"term": "Chronic Disease"}, {"term": "Medica...       False
# 1       [{"term": "Hypercholesterolemia"}, {"term": "O...       False
# 2                       [{"term": "Neoplasm Metastasis"}]       False
# 3                        [{"term": "Dermatitis, Atopic"}]        True
# 4                  [{"term": "Mitochondrial Myopathies"}]       False
# ...                                                   ...         ...
# 273090  [{"term": "Liver Cirrhosis"}, {"term": "Fibros...       False
# 273091                 [{"term": "Pancreatic Neoplasms"}]       False
# 273092                             [{"term": "COVID-19"}]       False
# 273093  [{"term": "Neoplasm Metastasis"}, {"term": "Ne...       False
# 273094                           [{"term": "Depression"}]       False
#
#                    who_masked maximum_age  \
# 0                         nan         nan
# 1             ["PARTICIPANT"]    60 Years
# 2                         nan         nan
# 3                         nan    75 Years
# 4                         nan         nan
# ...                       ...         ...
# 273090  ["OUTCOMES_ASSESSOR"]    80 Years
# 273091                    nan         nan
# 273092                    nan    55 Years
# 273093                    nan         nan
# 273094                    nan         nan
#
#                                   intervention_mesh_terms       why_stopped  \
# 0                                                     nan               nan
# 1                                   [{"term": "Methods"}]               nan
# 2       [{"term": "Vemurafenib"}, {"term": "cobimetini...               nan
# 3                                [{"term": "spesolimab"}]  Sponsor decision
# 4                                    [{"term": "Niacin"}]               nan
# ...                                                   ...               ...
# 273090                       [{"term": "Growth Hormone"}]               nan
# 273091  [{"term": "Fluorouracil"}, {"term": "Oxaliplat...               nan
# 273092              [{"term": "CVXGA1 COVID-19 vaccine"}]               nan
# 273093                                                nan               nan
# 273094                                                nan               nan
#
#        last_known_status duration_days
# 0                    nan         648.0
# 1                    nan         393.0
# 2                    nan        1174.0
# 3                    nan         883.0
# 4                    nan         585.0
# ...                  ...           ...
# 273090               nan        1064.0
# 273091               nan           NaN
# 273092               nan         673.0
# 273093               nan         942.0
# 273094               nan          81.0
#
# [273095 rows x 39 columns]

# %%
# Guardamos el archivo una vez limpiado, que se usará en el proximo paso

today = datetime.today().strftime("%Y%m%d_%H%M%S")
out_path = CLEAN_DIR / f"clinicaltrials_clean_{today}.csv"

df_clean.to_csv(out_path, index=False)

print("Dataset guardado en:")
out_path

# %% [markdown]
# - Se ha cargado correctamente el fichero RAW más reciente.
#
# - Se observa la estructura inicial de los datos tal y como vienen de la API.
#
# - Se ha realizado una limpieza:
#   - Normalización de nombres de columnas
#   - Conversión inicial de columnas de fechas
#   - Eliminación de formatos no estándar
#
# El resto del análisis se basará en el archivo generado en `data/clean/`:
# - `clinicaltrials_clean_YYYYMMDD_HHMMSS.csv`
